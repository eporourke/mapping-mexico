# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %%
ged211 = pd.read_excel('../data/a_ged211.xlsx')

# %%
ged211.head(10)
# Out:
#        id               relid  year  active_year code_status  \
# 0  244657  IRQ-2017-1-524-322  2017            1       Clear
# 1  132140    AFG-1989-1-411-2  1989            1       Clear
# 2  130364   AFG-1989-1-411-37  1989            1       Clear
# 3  130359    AFG-1989-1-411-4  1989            1       Clear
# 4  133883   AFG-1989-1-411-39  1989            1       Clear
# 5  133874    AFG-1989-1-411-6  1989            1       Clear
# 6  133878   AFG-1989-1-411-38  1989            1       Clear
# 7  133888   AFG-1989-1-411-40  1989            1       Clear
# 8  133891    AFG-1989-1-411-9  1989            1       Clear
# 9  133892    AFG-1989-1-411-7  1989            1       Clear
#
#    type_of_violence  conflict_dset_id  conflict_new_id  \
# 0                 1               259              259
# 1                 1               333              333
# 2                 1               333              333
# 3                 1               333              333
# ...

# %%
ged211_mex = ged211[ged211['country'].str.contains('Mexico')]
ged211_mex.shape
# Out:
# (7497, 49)

# %%
ged211_mex.head(10)
# Out:
#             id               relid  year  active_year code_status  \
# 107751  184766    MEX-1994-1-230-8  1994            1       Clear
# 107752  184720    MEX-1994-1-230-6  1994            1       Clear
# 107753  184722    MEX-1994-1-230-7  1994            1       Clear
# 107754  184765  MEX-1994-1-230-3.1  1994            1       Clear
# 107755  193587  MEX-1994-1-230-3.2  1994            1       Clear
# 107756  193588  MEX-1994-1-230-3.3  1994            1       Clear
# 107757  193589  MEX-1994-1-230-3.4  1994            1       Clear
# 107758  193590  MEX-1994-1-230-3.5  1994            1       Clear
# 107759  184763    MEX-1994-1-230-4  1994            1       Clear
# 107760  184764    MEX-1994-1-230-5  1994            1       Clear
#
#         type_of_violence  conflict_dset_id  conflict_new_id  \
# 107751                 1               400              400
# 107752                 1               400              400
# ...

# %%
#replace integers with their associated values
ged211_mex = ged211_mex["type_of_violence"].replace({
"1": "state-based",
"2": "non-state",
"3": "one-sided"})

# %%
# drop "code_status" column - data codebook states "Always clear, only used for monthly releases of candidate
# events, only available in the api 21.1 version, removed in the other formats for UCDP GED 21.1."
ged211_mex=ged211_mex.drop(columns=['code_status'])

# %%
# drop "conflict_dset_id" column - data codebook states "Only used in older versions of the dataset, exists but should
# not be used in the api 21.1 version, removed in the other formats for UCDP GED 21.1."
ged211_mex=ged211_mex.drop(columns=['conflict_dset_id'])

# %%
# drop "dyad_dset_id" column - data codebook states "Only used in older versions of the dataset, exists but should
# not be used in the api 21.1 version, removed in the other formats for UCDP GED 21.1"
ged211_mex=ged211_mex.drop(columns=['dyad_dset_id'])

# %%
# drop "side_a_dset_id" column - data codebook states "Only used in older versions of the dataset, exists but should
# not be used in the api 21.1 version, removed in the other formats for UCDP GED 21.1"
ged211_mex=ged211_mex.drop(columns=['side_a_dset_id'])

# %%
# drop "side_b_dset_id" column - data codebook states "Only used in older versions of the dataset, exists but should
# not be used in the api 21.1 version, removed in the other formats for UCDP GED 21.1"
ged211_mex=ged211_mex.drop(columns=['side_b_dset_id'])

# %%
ged211_mex=ged211_mex.drop(columns=['region'])
