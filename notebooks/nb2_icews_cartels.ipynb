# %% [markdown]
# # Notebook 2: Cleaning and narrowing dataset to cartel related events

# %%
import pandas as pd
import numpy as np
import datetime
#import geopandas as gp

# %%
#using full icews data set to screen for cartel events and make sure I'm not filtering anything out accidentally
cartel_df = pd.read_csv('../data/icews_main.csv', parse_dates=['event_date'],dtype={
       'event_id':'int','intensity':'float','story_id':'int','sentence_number':'int'})

# %%
#standardize events involving cartels, consolidating cartel factions to
#reflect umbrella organizations
cartels = {
    "Armed Gang (Sinaloa Cartel)": 'Sinaloa Cartel',
    "Armed Gang (Juárez Cartel)":'Juárez Cartel',
    "Organized Crime (Gulf Cartel)":'Gulf Cartel',
    "Armed Gang (Gulf Cartel)":'Gulf Cartel',
    "Drug Gang (Los Zetas Cartel)":'Los Zetas Cartel',
    "Hitman (Gulf Cartel)":'Gulf Cartel',
    "Hitman (Los Zetas Cartel)":'Los Zetas Cartel',
    "Criminal (Los Zetas Cartel)":'Los Zetas Cartel',
    "Drug Gang (Gulf Cartel)":'Gulf Cartel',
    "Armed Services Deserter (Los Zetas Cartel)":'Los Zetas Cartel',
    "Armed Gang (Knights Templar Cartel)":'Knights Templar Cartel',
    "La Familia Michoacana": 'La Familia Michoacana Cartel',
    "Drug Gang (La Familia Michoacana)": 'La Familia Michoacana Cartel',
    "La Línea": 'Juárez Cartel',
    "Criminal (La Línea)":'Juárez Cartel',
    "Barrio Azteca": 'Barrio Azteca Drug Gang',
    "Gente Nueva": "Sinaloa Cartel",
    "BeltrÃ¡n-Leyva Cartel": "Beltrán-Leyva Cartel",
    "Los Negros": "Beltrán-Leyva Cartel",
    "Mexicles": "Mexicles Drug Gang"
}
cartel_df = cartel_df.replace(cartels)

# %%
cartel_source = cartel_df.loc[cartel_df['source_name'].str.contains('Cartel')]
cartel_target = cartel_df.loc[cartel_df['target_name'].str.contains('Cartel')]
drug_gang_source = cartel_df.loc[cartel_df['source_name'].str.contains('Drug')]
drug_gang_target = cartel_df.loc[cartel_df['target_name'].str.contains('Drug')]

# %%
cartels = pd.concat([cartel_source, cartel_target, drug_gang_source, drug_gang_target])

# %%
cartels.shape
# Out:
# (13957, 21)

# %%
cartels['event_year'] = cartels['event_date'].dt.year

# %%
cartel_df["event_year"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'event_year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-f800308eaa9c> in <module>
# ----> 1 cartel_df["event_year"].value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'event_year'

# %%
cartels['event_year'].unique()
# Out:
# array([1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2017, 2018, 2019,
#        2020, 1995], dtype=int64)

# %%
cartels['country'].unique()
# Out:
# array(['Mexico', 'Peru', 'Colombia', 'Cuba', 'Panama', 'United States',
#        'Brazil', 'Venezuela', 'Guatemala', 'Italy', 'Canada', 'Spain',
#        'China', 'El Salvador', 'Ecuador', 'Costa Rica', 'Honduras',
#        'Nigeria', 'United Kingdom', 'Dominican Republic', 'Ireland',
#        'South Africa', 'New Zealand', 'Philippines', 'Bolivia', 'Jamaica',
#        'Thailand', 'Laos', 'Vietnam', 'Singapore', 'Chile', 'Japan',
#        'Australia', 'Austria', 'United Arab Emirates', 'Belize',
#        'Myanmar', 'Romania', 'Argentina', 'Tajikistan', 'Hong Kong',
#        'Saudi Arabia', 'Latvia', 'Germany', 'Kosovo',
#        'Trinidad and Tobago', 'Zambia', 'Russian Federation', 'Greece',
#        'Iran', 'Indonesia', 'Cambodia', 'Czech Republic', 'Turkey',
#        'Kazakhstan', 'Netherlands', 'Malaysia', 'Pakistan', 'India',
#        'Senegal', 'Afghanistan', 'Georgia', 'Lebanon', 'Angola',
#        'Bangladesh', 'Uruguay', 'France', 'South Korea', 'Nicaragua',
#        'Slovakia', 'Iraq', 'Bulgaria', 'Serbia', 'Gambia', 'Haiti',
#        'Taiwan', 'Kenya', 'Kyrgyzstan', 'Libya', 'Sudan', 'Israel',
#        'Occupied Palestinian Territory', 'Papua New Guinea', 'Poland',
#        'Suriname', 'Ghana', 'Azerbaijan', 'Zimbabwe', 'Turkmenistan',
#        'Liberia', 'Ukraine', 'Guinea-Bissau', 'Namibia', 'Egypt',
#        'Belgium', 'Uzbekistan', 'Morocco', 'Mali', 'Maldives',
#        'Switzerland', 'Tanzania', 'Burkina Faso', 'Puerto Rico',
#        'Paraguay', 'New Caledonia', 'Estonia', 'Albania', 'Holy See',
#        'Syria', 'Malawi', 'Ethiopia', 'Democratic Republic of Congo',
#        'Guyana', 'Hungary', 'Burundi', 'Fiji', 'Benin', 'Croatia',
#        'Lithuania', 'Kuwait', 'Oman', 'Qatar', 'Somalia', 'Norway',
#        'Belarus', 'Finland', 'Curaçao',
#        'the former Yugoslav Republic of Macedonia', 'Sri Lanka', 'Nepal',
#        'Guadeloupe', 'Montenegro', 'Sierra Leone', 'French Polynesia',
#        'Portugal', 'Mauritius', 'Uganda', 'Togo', 'Algeria', 'Sweden',
#        'Macao', 'Botswana', 'Mozambique', 'Gabon', 'Denmark',
#        'Bosnia and Herzegovina', 'Yemen', 'Rwanda', 'Vanuatu', 'Jordan',
#        'Mauritania', 'Slovenia', 'Congo'], dtype=object)

# %%
cartels['cameo_code'].unique()
# Out:
# array([ 180,   10,   42,   40,  173,   36,   71,  112,   43,   51,  181,
#         841,  356,  111, 1121,  193,   20,  130,   90,  313,   44,   63,
#         331,   12,  138,   60,   15, 1822,   32,   50,  874,   61, 1823,
#         192,   72,  100,   13, 1821,  190,  353,  125,   14,  174,  120,
#          64,  160,   30,  186,  154,   62,  163, 1621,   81,  141,   46,
#          70,   80,  183,   41,  113,  195,  311,  142,   16, 1122, 1711,
#         102,  182,  161,  833,  332, 1246,   74,   17,  214,   57,   22,
#         213, 1211,  115,  150,  191,   25,  128,   91,   18, 1125,  172,
#         842, 1031,  114,  231,   19,  194,  170,  202,  312,  139,  124,
#         132, 1243, 1041,  233,   21,  171,  145,  143, 1661,  253,   35,
#         184,  333,  256,   55, 1313,   45,   73,  861,   23,  137,   75,
#        1053,  133, 1241,  153,  105,  351,  127, 1712,   26,   37,   11,
#        1014,  106, 1056], dtype=int64)

# %%
cartels_v1 = cartels.loc[cartels["cameo_code"].isin([
180,181,182,183,184,185,186,190,191,192,193,194,195,202,1822,1823])]

# %%
cartels_v1.shape
# Out:
# (3066, 22)

# %%
cartels_v1['event_year'].unique()
# Out:
# array([1996, 1999, 2003, 2004, 2005, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2017, 2018, 2019, 2020, 1997, 2000, 2002, 1995, 1998,
#        2001, 2006], dtype=int64)

# %%
cartels_v1['country'].unique()
# Out:
# array(['Mexico', 'Guatemala', 'Colombia', 'United States', 'Venezuela',
#        'Peru', 'United Kingdom', 'Honduras', 'South Africa', 'Brazil',
#        'Philippines', 'Thailand', 'Singapore', 'Australia', 'Canada',
#        'Myanmar', 'Saudi Arabia', 'Hong Kong', 'Germany',
#        'Trinidad and Tobago', 'Iran', 'Ireland', 'Czech Republic',
#        'New Zealand', 'Nigeria', 'Senegal', 'China', 'Georgia', 'Lebanon',
#        'India', 'Bangladesh', 'Afghanistan', 'United Arab Emirates',
#        'Italy', 'Tajikistan', 'Kenya', 'Israel', 'Indonesia',
#        'Netherlands', 'Kazakhstan', 'Occupied Palestinian Territory',
#        'Russian Federation', 'Zambia', 'Japan', 'Haiti', 'Guinea-Bissau',
#        'Greece', 'Egypt', 'Dominican Republic', 'Cambodia', 'Ukraine',
#        'Malaysia', 'Turkey', 'Chile', 'Bulgaria', 'Jamaica', 'Argentina',
#        'Kyrgyzstan', 'Tanzania', 'Switzerland', 'Namibia', 'Paraguay',
#        'New Caledonia', 'Taiwan', 'Albania', 'Liberia', 'Pakistan',
#        'Uruguay', 'Spain', 'France', 'Latvia', 'Romania', 'Belgium',
#        'Serbia', 'Finland', 'Bolivia', 'Hungary', 'Croatia',
#        'Turkmenistan', 'Portugal', 'Libya', 'Gambia', 'Vanuatu',
#        'Costa Rica', 'Austria', 'Norway'], dtype=object)

# %%
cartels_v1.head()
# Out:
#          Unnamed: 0  event_id event_date           source_name  \
# 385783       385783   1348307 1996-12-30  Beltrán-Leyva Cartel
# 1507433     1507433   2501317 1999-11-30         Juárez Cartel
# 1509636     1509636   2503620 1999-12-02         Juárez Cartel
# 4503880     4503880   6555207 2003-10-14         Juárez Cartel
# 5330245     5330245   7779500 2004-09-13         Juárez Cartel
#
#                       source_sectors source_country  \
# 385783                           NaN         Mexico
# 1507433  Dissident,Criminals / Gangs         Mexico
# 1509636  Criminals / Gangs,Dissident         Mexico
# 4503880  Criminals / Gangs,Dissident         Mexico
# 5330245  Dissident,Criminals / Gangs         Mexico
#
#                               event_text  cameo_code  intensity  \
# 385783       Use unconventional violence         180       -9.0
# 1507433      Use unconventional violence         180       -9.0
# 1509636      Use unconventional violence         180       -9.0
# 4503880  Abduct, hijack, or take hostage         181       -9.0
# 5330245      Use unconventional violence         180       -9.0
#
#                      target_name  ...  story_id sentence_number  \
# 385783   Foreign Affairs (Japan)  ...  29239867               4
# 1507433         Citizen (Mexico)  ...  31812087               3
# 1509636         Citizen (Mexico)  ...  30238340               6
# 4503880             Men (Mexico)  ...  13698349               5
# 5330245              Gulf Cartel  ...  13883098               2
#
#                               publisher                  city district  \
# 385783     BBC Monitoring Latin America  Beltrán-Leyva Cartel      NaN
# 1507433  Servicio Universal de Noticias                Juarez      NaN
# 1509636                    Reuters News                Juarez      NaN
# 4503880          AP Spanish Worldstream                   NaN      NaN
# 5330245                        El Norte            Nuevo Leon      NaN
#
#                        state country      lat       lon  event_year
# 385783   Estado de Zacatecas  Mexico  22.1340 -103.0680        1996
# 1507433  Estado de Chihuahua  Mexico  31.7333 -106.4830        1999
# 1509636  Estado de Chihuahua  Mexico  31.7333 -106.4830        1999
# 4503880                  NaN  Mexico  19.4285  -99.1277        2003
# 5330245    Estado de Yucatan  Mexico  21.2667  -87.6167        2004
#
# [5 rows x 22 columns]

# %%
Mex = ['Mexico']
cartel_mex = cartels_v1[cartels_v1.country.isin(Mex)]

# %%
cartel_mex.head(15)
# Out:
#          Unnamed: 0  event_id event_date           source_name  \
# 385783       385783   1348307 1996-12-30  Beltrán-Leyva Cartel
# 1507433     1507433   2501317 1999-11-30         Juárez Cartel
# 1509636     1509636   2503620 1999-12-02         Juárez Cartel
# 4503880     4503880   6555207 2003-10-14         Juárez Cartel
# 5330245     5330245   7779500 2004-09-13         Juárez Cartel
# 5330248     5330248   7779503 2004-09-13         Juárez Cartel
# 5330277     5330277   7779532 2004-09-13         Juárez Cartel
# 5401885     5401885   7891128 2004-10-09         Juárez Cartel
# 5680028     5680028   8293506 2005-01-19        Tijuana Cartel
# 5725370     5725370   8363112 2005-02-04        Sinaloa Cartel
# 5727848     5727848   8366626 2005-02-05        Sinaloa Cartel
# 5798619     5798619   8468563 2005-03-02      Los Zetas Cartel
# 5875264     5875264   8579193 2005-03-29           Gulf Cartel
# 5924956     5924956   8649554 2005-04-14           Gulf Cartel
# 5925095     5925095   8649735 2005-04-14           Gulf Cartel
#
#                       source_sectors source_country  \
# 385783                           NaN         Mexico
# 1507433  Dissident,Criminals / Gangs         Mexico
# 1509636  Criminals / Gangs,Dissident         Mexico
# 4503880  Criminals / Gangs,Dissident         Mexico
# 5330245  Dissident,Criminals / Gangs         Mexico
# 5330248  Dissident,Criminals / Gangs         Mexico
# 5330277  Dissident,Criminals / Gangs         Mexico
# 5401885  Dissident,Criminals / Gangs         Mexico
# 5680028  Dissident,Criminals / Gangs         Mexico
# 5725370  Criminals / Gangs,Dissident         Mexico
# 5727848  Criminals / Gangs,Dissident         Mexico
# 5798619  Dissident,Criminals / Gangs         Mexico
# 5875264  Criminals / Gangs,Dissident         Mexico
# 5924956  Dissident,Criminals / Gangs         Mexico
# 5925095  Dissident,Criminals / Gangs         Mexico
#
#                                       event_text  cameo_code  intensity  \
# 385783               Use unconventional violence         180       -9.0
# 1507433              Use unconventional violence         180       -9.0
# 1509636              Use unconventional violence         180       -9.0
# 4503880          Abduct, hijack, or take hostage         181       -9.0
# 5330245              Use unconventional violence         180       -9.0
# 5330248              Use unconventional violence         180       -9.0
# 5330277              Use unconventional violence         180       -9.0
# 5401885              Use unconventional violence         180       -9.0
# 5680028          Abduct, hijack, or take hostage         181       -9.0
# 5725370              Use unconventional violence         180       -9.0
# 5727848              Use unconventional violence         180       -9.0
# 5798619  fight with small arms and light weapons         193      -10.0
# 5875264              Use unconventional violence         180       -9.0
# 5924956              Use unconventional violence         180       -9.0
# 5925095              Use unconventional violence         180       -9.0
#
#                      target_name  ...  story_id sentence_number  \
# 385783   Foreign Affairs (Japan)  ...  29239867               4
# 1507433         Citizen (Mexico)  ...  31812087               3
# 1509636         Citizen (Mexico)  ...  30238340               6
# 4503880             Men (Mexico)  ...  13698349               5
# 5330245              Gulf Cartel  ...  13883098               2
# 5330248              Gulf Cartel  ...  13883171               3
# 5330277              Gulf Cartel  ...  13883437               3
# 5401885                   Mexico  ...   4840572               3
# 5680028         Citizen (Mexico)  ...  14005527               2
# 5725370                   Mexico  ...   7094900               6
# 5727848                   Mexico  ...   2823271               6
# 5798619         Citizen (Mexico)  ...   5782761               3
# 5875264       Drug Gang (Mexico)  ...   4377306               6
# 5924956     Joaquín Guzmán Loera  ...   6340078               6
# 5925095                   Mexico  ...   6340600               5
#
#                                  publisher                  city district  \
# 385783        BBC Monitoring Latin America  Beltrán-Leyva Cartel      NaN
# 1507433     Servicio Universal de Noticias                Juarez      NaN
# 1509636                       Reuters News                Juarez      NaN
# 4503880             AP Spanish Worldstream                   NaN      NaN
# 5330245                           El Norte            Nuevo Leon      NaN
# 5330248                              Mural            Nuevo Leon      NaN
# 5330277                            Reforma            Nuevo Leon      NaN
# 5401885                   EFE News Service               Sinaloa      NaN
# 5680028     Servicio Universal de Noticias               Tijuana      NaN
# 5725370         Associated Press Newswires          Nuevo Laredo      NaN
# 5727848  United News of Bangladesh Limited          Nuevo Laredo      NaN
# 5798619         Associated Press Newswires                Cancun      NaN
# 5875264                       Reuters News          Nuevo Laredo      NaN
# 5924956         Associated Press Newswires          Nuevo Laredo      NaN
# 5925095                       Reuters News          Nuevo Laredo      NaN
#
#                              state country      lat       lon  event_year
# 385783         Estado de Zacatecas  Mexico  22.1340 -103.0680        1996
# 1507433        Estado de Chihuahua  Mexico  31.7333 -106.4830        1999
# 1509636        Estado de Chihuahua  Mexico  31.7333 -106.4830        1999
# 4503880                        NaN  Mexico  19.4285  -99.1277        2003
# 5330245          Estado de Yucatan  Mexico  21.2667  -87.6167        2004
# 5330248          Estado de Yucatan  Mexico  21.2667  -87.6167        2004
# 5330277          Estado de Yucatan  Mexico  21.2667  -87.6167        2004
# 5401885          Estado de Chiapas  Mexico  15.8931  -92.1298        2004
# 5680028  Estado de Baja California  Mexico  32.5027 -117.0040        2005
# 5725370       Estado de Tamaulipas  Mexico  27.4763  -99.5164        2005
# 5727848       Estado de Tamaulipas  Mexico  27.4763  -99.5164        2005
# 5798619     Estado de Quintana Roo  Mexico  21.1743  -86.8466        2005
# 5875264       Estado de Tamaulipas  Mexico  27.4763  -99.5164        2005
# 5924956       Estado de Tamaulipas  Mexico  27.4763  -99.5164        2005
# 5925095       Estado de Tamaulipas  Mexico  27.4763  -99.5164        2005
#
# [15 rows x 22 columns]

# %%
cartel_mex.shape
# Out:
# (1600, 22)

# %%
cartel_mex['event_year'].unique()
# Out:
# array([1996, 1999, 2003, 2004, 2005, 2007, 2008, 2009, 2010, 2011, 2012,
#        2013, 2014, 2018, 2019, 2020, 1997, 2000, 2002, 2017, 2006, 1998],
#       dtype=int64)

# %%
cartel_mex['event_year'].value_counts()
# Out:
# 2010    297
# 2011    219
# 2009    174
# 2008    172
# 2014    143
# 2007    137
# 2012    135
# 2013     65
# 2005     53
# 2019     50
# 2017     42
# 2006     42
# 2018     27
# 2004     17
# 1999      7
# 2020      4
# 1997      4
# 2002      4
# 2000      3
# 2003      2
# 1998      2
# 1996      1
# Name: event_year, dtype: int64

# %%
# NOT WORKING
# years = [2001,2002,2003,'2004','2005',
#     '2006','2007','2008','2009','2010','2011',
#     '2012','2013','2014','2015','2016']
# cartel_mex = cartel_mex.loc[cartel_mex.event_year.isin(years)]
# cartel_mex.shape

# %%
# state = ['Central America']
# cartel_mex = cartels_v1[cartels_v1.provice.isin(Mex)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-7abde11bd47a> in <module>
#       1 state = ['Central America']
# ----> 2 cartel_mex = cartels_v1[cartels_v1.provice.isin(Mex)]
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'provice'

# %%
cartel_mex['source_name'].unique()
# Out:
# array(['Beltrán-Leyva Cartel', 'Juárez Cartel', 'Tijuana Cartel',
#        'Sinaloa Cartel', 'Los Zetas Cartel', 'Gulf Cartel',
#        'La Familia Michoacana Cartel', 'Knights Templar Cartel',
#        'Attacker (Mexico)', 'Citizen (Mexico)', 'Criminal (Mexico)',
#        'Citizen (United States)', 'Drug Gang (Mexico)',
#        'Joaquín Guzmán Loera', 'Mexico', 'Mob (Mexico)',
#        'Military (Mexico)', 'Police (Mexico)', 'Barrio Azteca Drug Gang',
#        'Military Personnel (United States)',
#        'Military Personnel - Special (Mexico)', 'Mexican Army',
#        'Edgar Valdez Villarreal', 'Marine Corp (Mexico)',
#        'Armed Gang (Mexico)', 'Business (Mexico)',
#        'Miguel Treviño Morales', 'Secret Agent (Mexico)', 'Mexican Navy',
#        'Militia (Mexico)', 'Military Personnel (Mexico)', 'Men (Mexico)',
#        'Drug Dealer (Mexico)', 'Drug Gang (Brazil)', 'Mexicles Drug Gang',
#        'Drug Enforcement Administration', 'Drug Dealer (Brazil)',
#        'Governor (Mexico)', 'Police (Brazil)', 'United States',
#        'Government (Mexico)', 'Federal Police',
#        'Foreign Affairs (United States)', 'Border Patrol (United States)',
#        'Citizen (Israel)', 'Police (United States)',
#        'Armed Band (Mexico)', 'Secretariat (Mexico)',
#        'High Ranking Military Personnel (Mexico)', 'Secret Agent (Iran)',
#        'Immigrants (Mexico)', 'Central America',
#        'Army National Guard (Mexico)', 'Villager (Mexico)'], dtype=object)

# %%
cartel_mex.to_csv('../data/icews_cartels.csv')
